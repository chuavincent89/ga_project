# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# College-going culture has increasingly important to the US States, standardize test are required in order to enroll into the desired college. This project aim to provide insights to Oregon State Board of Education. To find out ACT and SAT participation rate of Oregon and the indicators may caused state have lower participation rate as compared to other states. How to further improve the participation rate in order to increase the High School Graduates college-going rate from current 55.6% to Oregon education goal of 80% by 2025.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Outside Research](#Outside-Research)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# # Datasets:
# **Datasets use for analysis:**
#
# * [`act_2017.csv`](../data/act_2017.csv): 2017 ACT Scores by States
# * [`act_2018.csv`](../data/act_2018.csv): 2018 ACT Scores by States
# * [`act_2019.csv`](../data/act_2019.csv): 2019 ACT Scores by States
#
# * [`sat_2017.csv`](../data/sat_2017.csv): 2017 SAT Scores by States
# * [`sat_2018.csv`](../data/sat_2018.csv): 2018 SAT Scores by States
# * [`sat_2019.csv`](../data/sat_2019.csv): 2019 SAT Scores by States
#
# * [`spending_funding_states.csv`](../data/spending_funding_states.csv): U.S. Public Education Spending Statistics by states
# * [`Median-Household-Income-by-State.csv`](../data/Median-Household-Income-by-State.csv): U.S. Census Bureau Median Income By State 2015-2019
# * [`act_sat_mandate.csv`](../data/act_sat_mandate.csv): U.S. States with standardized test mandate 2018-2019
# * [`state_abbreviations.csv`](../data/state_abbreviations.csv): US states, abbreviations and code table
# * [`Most-Recent-Cohorts-All-Data-Elements.csv`](../data/Most-Recent-Cohorts-All-Data-Elements.csv) **(Data set is large, readers will have to unzip)**: Institution-level data files for 1996-97 through 2019-20, field of study-level data files for the pooled 2014-15, 2015-16 award years through the pooled 2016-17, 2017-18 award years and crosswalk files for 2000-01 through 2018-19 that link the Department’s OPEID with an IPEDS UNITID for each institution
#
# **Date Source Remarks:**
# - Base on 51 US States
# - Included District of Columbia (Washington DC) as a state
# - Excluded territories e.g. Puerto Rico, Virgin Islands

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# According to [NCHEMS Information Center](http://www.higheredinfo.org/dbrowser/?year=2016&level=nation&mode=data&state=&submeasure=63#/-1/), statistics shows that the Oregon having below than National Average High School Graduates College-going rate as per graph below
# <img src="../img/oregon_college_going.png" width="700" height="700" />
#
# We also found that Oregon have a Education Goal aim to achieve by year 2025, according to [Oregon Gov](https://www.oregon.gov/highered/research/Pages/educational-attainment.aspx)
# > "Known as the “40-40-20”, this goal established a clear target against which to gauge the state’s educational progress"
#
# In other word, Oregon aim to have 80% of College-Going rate by 2025
#
# <img src="../img/oregon_2025.png" width="700" height="700" />

# %% [markdown]
# ### Coding Challenges
#
# 1. **Manually calculate mean:**
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# create a average function for list of numbers
def avg(list_numbers):
    total = 0
    for number in list_numbers:
        total += number
    return total/len(list_numbers)

# %% [markdown]
# 2. **Manually calculate standard deviation:**
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Create standard_dev as standard deviation function
def standard_dev(list_numbers):
    total = 0
    for number in list_numbers:
        total += (number - avg(list_numbers))**2
    return ((total/len(list_numbers))**0.5)

# %% [markdown]
# 3. **Data cleaning function:**
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# create a function to convert string type percentage to float data
def convert_str_percentage(str_percentage):
    return round(float(str_percentage.replace('%',''))/100,4)

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports libraries needed for usage
import pandas as pd , numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# read and load dataset
act_2017 = pd.read_csv('../data/act_2017.csv') #act 2017
act_2018 = pd.read_csv('../data/act_2018.csv') #act 2018
act_2019 = pd.read_csv('../data/act_2019.csv') #act 2019
sat_2017 = pd.read_csv('../data/sat_2017.csv') #sat 2017
sat_2018 = pd.read_csv('../data/sat_2018.csv') #sat 2018
sat_2019 = pd.read_csv('../data/sat_2019.csv') #sat 2019

#additional source of datasets
state_code = pd.read_csv('../data/state_abbreviations.csv') #state abbreviations
spend_funding = pd.read_csv('../data/spending_funding_states.csv') # fed and state spending and funding

#act sat test mandate
test_mandate = pd.read_csv('../data/act_sat_mandate.csv') 
test_mandate = test_mandate[['state','test_mandate']]

#Average Median Household Income 2015-2019
median_hh_income = pd.read_csv('../data/Median-Household-Income-by-State.csv',skiprows=1) 

#all raw data for most recent cohorts, use low memory to prevent DtypeWarning
all_data_elements = pd.read_csv('../data/Most-Recent-Cohorts-All-Data-Elements.csv',low_memory = False)
total_uni = all_data_elements[['INSTNM','STABBR']] #filtered the columns needed

#['AS', 'GU', 'MP', 'PR', 'FM', 'PW', 'VI', 'MH'] have to remove from the dataframe
total_uni = total_uni[~total_uni.STABBR.isin(['AS', 'GU', 'MP', 'PR', 'FM', 'PW', 'VI', 'MH'])]

# %%
# lower case columnns name
act_2017.columns = act_2017.columns.str.lower()
act_2018.columns = act_2018.columns.str.lower()
act_2019.columns = act_2019.columns.str.lower()
sat_2017.columns = sat_2017.columns.str.lower()
sat_2018.columns = sat_2018.columns.str.lower()
sat_2019.columns = sat_2019.columns.str.lower()
spend_funding.columns = spend_funding.columns.str.lower()
state_code.columns = state_code.columns.str.lower()
total_uni.columns = total_uni.columns.str.lower()
median_hh_income.columns = median_hh_income.columns.str.lower()

# %%
# remove unnecessary columns
act_2017.drop(columns=['english','math','reading','science'],inplace=True)
sat_2017.drop(columns=['evidence-based reading and writing','math'],inplace=True)
sat_2018.drop(columns=['evidence-based reading and writing','math'],inplace=True)
sat_2019.drop(columns=['ebrw','math'],inplace=True)
state_code.drop(columns=['abbrev'], inplace=True)
median_hh_income.drop(columns=['margin of error'], inplace=True)

# %%
# trim the data in the columns 
act_2017.participation = act_2017.participation.str.strip()

# %%
# rename the column
act_2017.rename(columns = {'composite':'score'},inplace=True) 
act_2018.rename(columns = {'composite':'score'},inplace=True) 
act_2019.rename(columns = {'composite':'score'},inplace=True) 
sat_2017.rename(columns = {'total':'score'} ,inplace=True) 
sat_2018.rename(columns = {'total':'score'} ,inplace=True) 
sat_2019.rename(columns = {'participation rate':'participation','total':'score'} ,inplace=True) 
total_uni.rename(columns = {'stabbr':'code','instnm':'uni_name'}, inplace = True)
spend_funding.rename(columns = {'stabbr':'code',' k-12 spending ':'k12_spending',
                                ' postsecondary spending ':'postsec_spending',
                                ' federal funding ':'fed_funding',' state & local funding ':'state_funding'}, inplace = True)

# %%
# remove irrelevant rows
act_2017.drop(labels=0, inplace=True) #0 National, for simplicity, the State column includes 50 states + capital city of US
act_2018.drop(labels=19, inplace=True) # 19, duplicate row for state 'Maine'
act_2019.drop(labels=51, inplace=True) #51 National
sat_2019.drop(labels=[39,47], inplace=True) #39 Puerto Rico and 47 Virgin Islands 
median_hh_income.drop(labels=[51,52], inplace=True) #51 Puerto Rico and 52 is source

# %%
# apply convert_str_percentage function to participation column
act_2017.participation = act_2017.participation.apply(convert_str_percentage)
act_2018.participation = act_2018.participation.apply(convert_str_percentage)
act_2019.participation = act_2019.participation.apply(convert_str_percentage)
sat_2017.participation = sat_2017.participation.apply(convert_str_percentage)
sat_2018.participation = sat_2018.participation.apply(convert_str_percentage)
sat_2019.participation = sat_2019.participation.apply(convert_str_percentage)

# %%
# Replace and rectify entry error, typo and unknown value
act_2017.score.replace('20.2x',20.2, inplace=True)
act_2018.state.replace('District of columbia','District of Columbia',inplace=True)

# %%
# convert object type to float / int data type
act_2017.score = act_2017.score.astype('float') #act_2017

#median household income
median_hh_income.income = median_hh_income.income.apply(lambda x: int(x.replace('$','').replace(',','')))

#spend_funding
spend_funding.k12_spending = spend_funding.k12_spending.apply(lambda x: int(x.replace('.00','').replace(',','')))
spend_funding.postsec_spending =spend_funding.postsec_spending.apply(lambda x: int(x.replace('.00','').replace(',','')))
spend_funding.fed_funding = spend_funding.fed_funding.apply(lambda x: int(x.replace('.00','').replace(',','')))
spend_funding.state_funding = spend_funding.state_funding.apply(lambda x: int(x.replace('.00','').replace(',','')))

# %%
# creating new metrics by adding new columns
# add score_percent column to show percentage out of full mark, ACT full mark at 36, SAT full mark at 1600
act_2017['score_percent'] = round(act_2017.score/36,4)
act_2018['score_percent'] = round(act_2018.score/36,4)
act_2019['score_percent'] = round(act_2019.score/36,4)

sat_2017['score_percent'] = round(sat_2017.score/1600,4)
sat_2018['score_percent'] = round(sat_2018.score/1600,4)
sat_2019['score_percent'] = round(sat_2019.score/1600,4)

# %%
# categorize dataframe as test type ACT and year
act_2017['test'] = 'ACT'
act_2018['test'] = 'ACT'
act_2019['test'] = 'ACT'
sat_2017['test'] = 'SAT'
sat_2018['test'] = 'SAT'
sat_2019['test'] = 'SAT'

act_2017['year'] = '2017'
act_2018['year'] = '2018'
act_2019['year'] = '2019'
sat_2017['year'] = '2017'
sat_2018['year'] = '2018'
sat_2019['year'] = '2019'

# %%
# print head, info and describe the dataframe
dict_df = {'act_2017':act_2017,'act_2018':act_2018,'act_2019':act_2019,
           'sat_2017':sat_2017,'sat_2018':sat_2018,'sat_2019':sat_2019,
           'state_code':state_code,'total_uni':total_uni,'spend_funding':spend_funding,
           'test_mandate':test_mandate, 'median_hh_income':median_hh_income}

for df_name, df in dict_df.items():
    print (f'{df_name} print first 5 rows:')
    print (df.head())
    print ('\n')
    print (f'{df_name} print data info:')
    print (df.info())
    print ('\n')
    print (f'{df_name} print data describe:')
    print (df.describe())
    print ('----------------------------------------------------------------')
# Out:
# act_2017 print first 5 rows:
#         state  participation  score  score_percent test  year
# 1     Alabama           1.00   19.2         0.5333  ACT  2017
# 2      Alaska           0.65   19.8         0.5500  ACT  2017
# 3     Arizona           0.62   19.7         0.5472  ACT  2017
# 4    Arkansas           1.00   19.4         0.5389  ACT  2017
# 5  California           0.31   22.8         0.6333  ACT  2017
#
#
# act_2017 print data info:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 1 to 51
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          51 non-null     object
#  1   participation  51 non-null     float64
#  2   score          51 non-null     float64
#  3   score_percent  51 non-null     float64
#  4   test           51 non-null     object
#  5   year           51 non-null     object
# dtypes: float64(3), object(3)
# memory usage: 2.8+ KB
# None
#
#
# ...

# %% [markdown]
# ### Merging Dataframe

# %%
# concat for long format dataframe as df_act_sat_long
df_act_sat_long = pd.concat([act_2017,act_2018,act_2019,sat_2017,sat_2018,sat_2019],ignore_index=True)

# %%
# filter ACT, group by state and take mean on participation and score percent
df_act_mean = df_act_sat_long[df_act_sat_long['test']=='ACT'].groupby(
    ['state'])[['participation','score_percent']].mean().reset_index()

# filter SAT, group by state and take mean on participation and score percent
df_sat_mean = df_act_sat_long[df_act_sat_long['test']=='SAT'].groupby(['state'])[
    ['participation','score_percent']].mean().reset_index()

# Merge both filtered ACT and SAT into wide dataframe
df_act_sat_wide = pd.merge(df_act_mean, df_sat_mean, on='state', suffixes=('_act','_sat'))

# Merge the state_code into the total_uni dataframe
total_uni = pd.merge(total_uni, state_code, on ='code')
total_uni = total_uni.groupby(['code','state']).agg({'uni_name':
                                                       'count'}).reset_index().round(2).rename(columns={'uni_name':'total_uni'})

# Merge in total_uni datasets
df_act_sat_wide = pd.merge(df_act_sat_wide, total_uni, on='state')

# Merge in median_hh_income datasets
df_act_sat_wide = pd.merge(df_act_sat_wide, median_hh_income, on='state')

# Merge in spend_funding datasets
df_act_sat_wide = pd.merge(df_act_sat_wide, spend_funding, on='state')

# Merge in test_mandate datasets
df_act_sat_wide = pd.merge(df_act_sat_wide, test_mandate, on='state')

# %%
df_act_sat_wide.head()
# Out:
#         state  participation_act  score_percent_act  participation_sat  \
# 0     Alabama           1.000000           0.529633           0.060000
# 1      Alaska           0.453333           0.562033           0.406667
# 2     Arizona           0.670000           0.536100           0.300000
# 3    Arkansas           1.000000           0.537967           0.046667
# 4  California           0.270000           0.630567           0.586667
#
#    score_percent_sat code  total_uni  income  k12_spending  postsec_spending  \
# 0           0.723767   AL         89   50536          9752             32179
# 1           0.683933   AK          9   77640         17984             32630
# 2           0.708133   AZ        114   58945          8044             18614
# 3           0.732900   AR         92   47597         10184             29953
# 4           0.665833   CA        693   75235         12728             27495
#
#    fed_funding  state_funding test_mandate
# ...

# %%
df_act_sat_wide.corr()
# Out:
#                    participation_act  score_percent_act  participation_sat  \
# participation_act           1.000000          -0.861335          -0.867447
# score_percent_act          -0.861335           1.000000           0.733799
# participation_sat          -0.867447           0.733799           1.000000
# score_percent_sat           0.679405          -0.432134          -0.856325
# total_uni                  -0.207401           0.145257           0.193580
# income                     -0.516665           0.582463           0.486730
# k12_spending               -0.541186           0.665709           0.478367
# postsec_spending           -0.197388           0.212782           0.112589
# fed_funding                 0.023414          -0.168672          -0.071954
# state_funding              -0.524259           0.645011           0.495740
#
#                    score_percent_sat  total_uni    income  k12_spending  \
# ...

# %%
# creating new metrics by add new columns
# fed funding per student over median household income
df_act_sat_wide['fed_fund_per_mincome'] = df_act_sat_wide.fed_funding / df_act_sat_wide.income

# state funding per student over median household income
df_act_sat_wide['state_fund_per_mincome'] = df_act_sat_wide.state_funding / df_act_sat_wide.income

# %%
# Merge data frame for ACT 2017 and 2018
df_act = pd.merge(act_2017[['state','participation','score_percent']] ,
                  act_2018[['state','participation','score_percent']], on='state',suffixes=('_act_2017','_act_2018'))

# Merge data frame for df act and 2019
df_act = pd.merge(df_act,act_2019[['state','participation','score_percent']],
                  on='state').rename(columns={'participation':'participation_act_2019',
                                                              'score':'score_act_2019',
                                                              'score_percent':'score_percent_act_2019'})

# Merge data frame for SAT 2017 and 2018
df_sat = pd.merge(sat_2017[['state','participation','score_percent']],
                  sat_2018[['state','participation','score_percent']], on='state',suffixes=('_sat_2017','_sat_2018'))

# Merge data frame for df SAT and 2019
df_sat = pd.merge(df_sat,sat_2019[['state','participation','score_percent']],
                  on='state').rename(columns={'participation':'participation_sat_2019',
                                                              'score':'score_sat_2019',
                                                              'score_percent':'score_percent_sat_2019'})

# Merge both dataframe for ACT and SAT into df combine
df_combine = pd.merge(df_act,df_sat,on='state')

# %%
#Save cleaned and merged dataframes as csv files.
df_act_sat_long.to_csv('../data/act_sat_long.csv',index=False) 
df_act_sat_wide.to_csv('../data/act_sat_wide.csv',index=False) 
df_combine.to_csv('../data/combine.csv',index=False)

# %% [markdown]
# ## Data Dictionary
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|df_act_sat_long / df_act_sat_wide / df_combine|Names of all US states and District of Columbia|
# |participation|float|df_act_sat_long|The percentage of participation rate who took the ACT or SAT (0.9810 means 98.1%)|
# |score|float|df_act_sat_long|The total score of of the test on ACT or SAT|
# |score_percent|float|df_act_sat_long|The percentage of score out of full mark (ACT full mark is 36, SAT full mark is 1600)|
# |test|object|df_act_sat_long|The test type (ACT or SAT)|
# |year|object|df_act_sat_long|The year of attending the ACT or SAT|
# |participation_act|float|df_act_sat_wide|Average percentage of participation rate who took the ACT from 2017 - 2019(0.9810 means 98.1%)|
# |participation_sat|float|df_act_sat_wide|Average percentage of participation rate who took the SAT from 2017 - 2019(0.9810 means 98.1%)|
# |score_percent_act|float|df_act_sat_wide|Average percentage of score out of full mark for ACT from 2017 - 2019(ACT full mark is 36)|
# |score_percent_sat|float|df_act_sat_wide|Average percentage of score out of full mark for SAT from 2017 - 2019(SAT full mark is 1600)|
# |code|object|df_act_sat_wide|Postal abbreviations of all US states and District of Columbia|
# |income|float|df_act_sat_wide|US States Average median household income (2015 - 2019)|
# |total_uni|int|df_act_sat_wide|The total numbers of university / college institution in each US state|
# |k12_spending|int|df_act_sat_wide|US States K12 spending per student|
# |postsec_spending|int|df_act_sat_wide|US States Postsecondary spending per student|
# |fed_funding|int|df_act_sat_wide|US States Federal funding per student|
# |state_funding|int|df_act_sat_wide|US statas and local funding per student|
# |fed_fund_per_mincome|float|df_act_sat_wide|US States Federal funding per student per Median Household Income|
# |state_fund_per_mincome|float|df_act_sat_wide|US States State and Local funding per student per Median Household Income|
# |test_mandate|object|df_act_sat_wide|US States with ACT or SAT mandate requirement 2018 - 2019|
# |participation_act_2017|float|df_combine|The percentage of participation rate who took the ACT in 2017(0.9810 means 98.1%)|
# |participation_act_2018|float|df_combine|The percentage of participation rate who took the ACT in 2018(0.9810 means 98.1%)|
# |participation_act_2019|float|df_combine|The percentage of participation rate who took the ACT in 2019(0.9810 means 98.1%)|
# |participation_sat_2017|float|df_combine|The percentage of participation rate who took the SAT in 2017(0.9810 means 98.1%)|
# |participation_sat_2018|float|df_combine|The percentage of participation rate who took the SAT in 2018(0.9810 means 98.1%)|
# |participation_sat_2019|float|df_combine|The percentage of participation rate who took the SAT in 2019(0.9810 means 98.1%)|
# |score_percent_act_2017|float|df_combine|The percentage of score out of full mark for ACT in 2017(ACT full mark is 36)|
# |score_percent_act_2018|float|df_combine|The percentage of score out of full mark for ACT in 2018(ACT full mark is 36)|
# |score_percent_act_2019|float|df_combine|The percentage of score out of full mark for ACT in 2019(ACT full mark is 36)|
# |score_percent_sat_2017|float|df_combine|The percentage of score out of full mark for SAT in 2017(SAT full mark is 1600)|
# |score_percent_sat_2018|float|df_combine|The percentage of score out of full mark for SAT in 2018(SAT full mark is 1600)|
# |score_percent_sat_2019|float|df_combine|The percentage of score out of full mark for SAT in 2019(SAT full mark is 1600)|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### Standard Deviation of Each Numeric Column

# %%
# dictionary comprehension for dataframe df_act_sat_long and df_act_sat_wide
print('standard deviation for df_act_sat_long:')
print({col.name:standard_dev(col) for col in 
            [df_act_sat_long[i] for i in df_act_sat_long.columns if 
             (df_act_sat_long[i].dtype =='float64') or (df_act_sat_long[i].dtype =='int64')]})
print('\n')
print('standard deviation for df_act_sat_wide:')
print({col.name:standard_dev(col) for col in 
            [df_act_sat_wide[i] for i in df_act_sat_wide.columns if 
             (df_act_sat_wide[i].dtype =='float64') or (df_act_sat_wide[i].dtype =='int64')]})
# Out:
# standard deviation for df_act_sat_long:
# {'participation': 0.36224958943749175, 'score': 553.1170713114219, 'score_percent': 0.07775766369508233}
#
#
# standard deviation for df_act_sat_wide:
# {'participation_act': 0.32545983794169353, 'score_percent_act': 0.057153955717805155, 'participation_sat': 0.35400606719772265, 'score_percent_sat': 0.0563007278544393, 'total_uni': 131.3683025359923, 'income': 10609.564094498826, 'k12_spending': 3891.149458800914, 'postsec_spending': 5848.429423334368, 'fed_funding': 387.2013455148027, 'state_funding': 4170.929756567187, 'fed_fund_per_mincome': 0.006546302721618012, 'state_fund_per_mincome': 0.046725732113785695}

# %%
# filter out National average participation rate, score and score percent for each test in (2017-2019)
df_act_sat_long.groupby('test').mean()
# Out:
#       participation        score  score_percent
# test
# ACT        0.618824    21.493464       0.597041
# SAT        0.448693  1119.732026       0.699831

# %% [markdown]
# ACT have higher average participation rate as compared to SAT participation rate, however we realize that the score percent of SAT averagely higher than ACT score percent. This is because the increasing percentage of mid-tier students tend to lower down the overall average of the score and vice versa

# %%
# filter out National average participation rate,score and score percent of each test for 3 years
df_act_sat_long.groupby(['test','year']).mean().T
# Out:
# test                 ACT                                SAT               \
# year                2017       2018       2019         2017         2018
# participation   0.652549   0.617255   0.586667     0.398039     0.457451
# score          21.519608  21.496078  21.464706  1126.098039  1120.019608
# score_percent   0.597765   0.597118   0.596239     0.703814     0.700006
#
# test
# year                  2019
# participation     0.490588
# score          1113.078431
# score_percent     0.695675

# %% [markdown]
# Although ACT have higher participation rate as compared to SAT, but the rate is decreasing over the years from 2017-2019. Whereas SAT participation rate is increasing over the years from 2017 - 2019. Both ACT and SAT score have been decreasing over the years

# %% [markdown]
# ### Lowest Participation Rate in ACT in 2017, 2018 and 2019

# %%
# Continuous lowest participation rate of ACT test for 3 years
df_act_sat_long[(df_act_sat_long.test == 'ACT')].sort_values(['participation','year']).head()
# Out:
#             state  participation  score  score_percent test  year
# 121         Maine           0.06   24.3         0.6750  ACT  2019
# 70          Maine           0.07   24.0         0.6667  ACT  2018
# 19          Maine           0.08   24.3         0.6750  ACT  2017
# 141  Rhode Island           0.12   24.7         0.6861  ACT  2019
# 109      Delaware           0.13   24.1         0.6694  ACT  2019

# %%
# to check participation rate of Maine on SAT for 3 years
df_act_sat_long[(df_act_sat_long.test == 'SAT')&(df_act_sat_long.state == 'Maine')]
# Out:
#      state  participation   score  score_percent test  year
# 172  Maine           0.95  1012.0         0.6325  SAT  2017
# 223  Maine           0.99  1013.0         0.6331  SAT  2018
# 274  Maine           0.99  1013.0         0.6331  SAT  2019

# %%
# filter out Maine average participation rate and score percent by test
df_act_sat_long[df_act_sat_long.state == 'Maine'].groupby('test')[['participation','score_percent']].mean()
# Out:
#       participation  score_percent
# test
# ACT        0.070000       0.672233
# SAT        0.976667       0.632900

# %% [markdown]
# By filtering out the lowest participation rate for ACT test over 2017 - 2019, it found that Maine is the only state consistenly having the lowest participation rate of 8% in 2017, 7% in 2018 and 6% in 2019. The rate is lowest in nationwide and it is decreasing over the years. However, by looking at Maine on SAT participation rate, it shows that the state have relatively high in participation rate with 2017 95%, 2018 99% and 2019 99%.
#
# According to [Education Week](https://www.edweek.org/teaching-learning/which-states-require-students-to-take-the-sat-or-act), Maine have the mandate to complete the SAT test in highschool, which means that SAT is default option and necessary for highschool students to participate, hence it shows that ACT having lowest participation rate. As ACT is optional test for Maine, some students may choose to attend both standardize test to obtain better result for college enrollment.
#
# It can be shown from the average score, ACT tend to have better average score percent (67.22%) than SAT score percent (63.29%). For Maine, SAT score tend to be stable over 2017 to 2019.
#
# Therefore, this is bias to categorize Maine as low in participation rate to standardized test.

# %% [markdown]
# ### Lowest Participation Rate in SAT in 2017, 2018 and 2019

# %%
# Continuous lowest participation rate of SAT test for 3 years
df_act_sat_long[(df_act_sat_long.test == 'SAT')].sort_values(['participation','year']).head()
# Out:
#             state  participation   score  score_percent test  year
# 168          Iowa           0.02  1275.0         0.7969  SAT  2017
# 177   Mississippi           0.02  1242.0         0.7762  SAT  2017
# 187  North Dakota           0.02  1256.0         0.7850  SAT  2017
# 238  North Dakota           0.02  1283.0         0.8019  SAT  2018
# 289  North Dakota           0.02  1263.0         0.7894  SAT  2019

# %%
# to check participation rate of North Dakota on ACT for 3 years
df_act_sat_long[(df_act_sat_long.test == 'ACT')&(df_act_sat_long.state == 'North Dakota')]
# Out:
#             state  participation  score  score_percent test  year
# 34   North Dakota           0.98   20.3         0.5639  ACT  2017
# 85   North Dakota           0.98   20.3         0.5639  ACT  2018
# 136  North Dakota           0.96   19.9         0.5528  ACT  2019

# %%
# filter out North Dakota average participation rate and score percent by test
df_act_sat_long[df_act_sat_long.state == 'North Dakota'].groupby('test')[['participation','score_percent']].mean()
# Out:
#       participation  score_percent
# test
# ACT        0.973333         0.5602
# SAT        0.020000         0.7921

# %% [markdown]
# By filtering out the lowest participation rate for SAT test over 2017 - 2019, it found that North Dakota is the only state consistenly having the lowest participation rate of only 2% in 2017, 2018 and 2019. However, by looking at North Dakota on ACT participation rate, it shows that the state have relatively high in participation rate with 2017 98%, 2018 98% and 2019 96%.
#
# According to [Education Week](https://www.edweek.org/teaching-learning/which-states-require-students-to-take-the-sat-or-act), North Dakota have the mandate that students must take ACT or WorkKeys and the districts may substitute ACT for state highschool test, which means that ACT is necessary option for highschool students to participate, hence it shows that SAT having lowest participation rate. As SAT is optional test for North Dakota, some students may also choose to attend both standardize test to obtain better result for college enrollment.
#
# It can be shown from the average score, SAT tend to have better average score percent (79.21%) than SAT score percent (56.02%). For North Dakota, ACT score tend to be stable over 2017 to 2019.
#
# Therefore, this is bias to categorize North Dakota as low in participation rate to standardized test.

# %% [markdown]
# ### Lowest Average Participation Rate on Both Test From 2017 to 2019

# %%
# filter out the lowest average participation rate for both test over 2017 to 2019
df_act_sat_long.groupby('state')[['participation','score_percent']].mean().sort_values('participation').head()
# Out:
#               participation  score_percent
# state
# Iowa               0.348333       0.696483
# Kansas             0.380000       0.690900
# South Dakota       0.401667       0.690233
# New Mexico         0.401667       0.614533
# California         0.428333       0.648200

# %%
# describe the dataframe and check the average participation rate
df_act_sat_long.describe()
# Out:
#        participation        score  score_percent
# count     306.000000   306.000000     306.000000
# mean        0.533758   570.612745       0.648436
# std         0.362843   554.023079       0.077885
# min         0.020000    17.700000       0.491700
# 25%         0.200000    21.300000       0.589975
# 50%         0.550000   484.300000       0.657800
# 75%         0.957500  1098.750000       0.693925
# max         1.000000  1298.000000       0.811200

# %% [markdown]
# On average participation rate for both test over 2017-2019, data shows that Iowa have the lowest average participation rate of 34.83%. Iowa also have far below than national average (53.38%). However this is difficult to conclude that Iowa having low in participation rate.

# %%
# filter out Iowa average participation rate and score percent by test
df_act_sat_long[df_act_sat_long.state == 'Iowa'].groupby('test')[['participation','score_percent']].mean()
# Out:
#       participation  score_percent
# test
# ACT        0.670000       0.604633
# SAT        0.026667       0.788333

# %% [markdown]
# Although Iowa have lowest average participation rate overally across nation, by further filtering out by test, it shows that Iowa have low participation rate in SAT with average of 2.67% while ACT participation rate averagely at 67%. Hence the overall low participation rate is due too low participation rate in SAT.
#
# The date shows that Iowa have ACT participation rate that is above national average ACT participation rate of 61.88%. According to [Education Week](https://www.edweek.org/teaching-learning/which-states-require-students-to-take-the-sat-or-act), Iowa does not have any mandate on SAT or ACT, so it only shows that Iowa have more preference on ACT test than SAT test.
#
# Statisics from [NCHEMS](http://www.higheredinfo.org/dbrowser/?year=2018&level=nation&mode=data&state=&submeasure=63) shows that Iowa college-going rate was 65.98% and it was above national average (63.65%).
#
# It also shows that the SAT have relatively higher score percent than ACT as ACT have higher participation rate than SAT, so the higher the participation rate of one test tend to have lower score percent.
#
# Therefore, this is also bias to categorize Iowa as low in participation rate to standardized test.

# %% [markdown]
# ### State with Participation Rate Consistenly Fall Below 52% for ACT and SAT in 2017, 2018 and 2019

# %% [markdown]
# From Maine, North Dakota and Iowa, it shows that is bias to filter the datasets by using lowest in test participation over the years and lowest overall participation rate as it may not reflect the truth behind whether is state mandate or preference.

# %%
# filter out the participation rate less than 52% consistently from 2017 to 2019 on both test
df_combine[(df_combine.participation_act_2017 < 0.52) & (df_combine.participation_act_2018 < 0.52) & 
           (df_combine.participation_act_2019 < 0.52) & (df_combine.participation_sat_2017 < 0.52) & 
           (df_combine.participation_sat_2018 < 0.52) & (df_combine.participation_sat_2019 < 0.52)]
# Out:
#      state  participation_act_2017  score_percent_act_2017  \
# 37  Oregon                     0.4                  0.6056
#
#     participation_act_2018  score_percent_act_2018  participation_act_2019  \
# 37                    0.42                  0.5917                    0.42
#
#     score_percent_act_2019  participation_sat_2017  score_percent_sat_2017  \
# 37                  0.5861                    0.43                  0.6925
#
#     participation_sat_2018  score_percent_sat_2018  participation_sat_2019  \
# 37                    0.48                  0.6981                    0.51
#
#     score_percent_sat_2019
# 37                   0.695

# %%
# filter out state with Oregon
df_act_sat_long[df_act_sat_long.state =='Oregon']
# Out:
#       state  participation   score  score_percent test  year
# 37   Oregon           0.40    21.8         0.6056  ACT  2017
# 88   Oregon           0.42    21.3         0.5917  ACT  2018
# 139  Oregon           0.42    21.1         0.5861  ACT  2019
# 190  Oregon           0.43  1108.0         0.6925  SAT  2017
# 241  Oregon           0.48  1117.0         0.6981  SAT  2018
# 292  Oregon           0.51  1112.0         0.6950  SAT  2019

# %%
# filter out Oregon average participation rate and score percent by test
df_act_sat_long[df_act_sat_long.state == 'Oregon'].groupby('test')[['participation','score_percent']].mean()
# Out:
#       participation  score_percent
# test
# ACT        0.413333       0.594467
# SAT        0.473333       0.695200

# %% [markdown]
# Oregon is the only state that was consistently fall below 52% participation rate on ACT and SAT in 2017, 2018 and 2019. The data shows that Oregon have average 41.33% in ACT participation rate and 47.33% in SAT participation rate. Both test showing an increasing trend in participation rate from 2017 - 2019, however SAT gain the most improvement in participation rate. SAT participation rate in 2019 had increased by 18.6% from 2017 SAT participation rate.
#
# Although SAT participation rate is increasing, data shows that the score percent tend to maintain as 69.52% while ACT participation rate have low in increament, and scoer pecent showing decreasing trend.
#
# According to [Education Week](https://www.edweek.org/teaching-learning/which-states-require-students-to-take-the-sat-or-act), Oregon does not have any mandate on SAT or ACT. Although it shows slightly preference on SAT over ACT, overally both standardized test still showing weak in participation rate which less than 52% and it bring the caution to the state.
#
# Besides that, Statisics from [NCHEMS](http://www.higheredinfo.org/dbrowser/?year=2018&level=nation&mode=data&state=&submeasure=63) shows that Oregon college-going rate was only 55.63% and it was far below than the national average (63.65%).

# %%
# check the percentage of the states having on different test mandate
df_act_sat_wide.test_mandate.value_counts(normalize=True)
# Out:
# NO         0.352941
# ACT        0.274510
# ACT/SAT    0.196078
# SAT        0.176471
# Name: test_mandate, dtype: float64

# %%
# check the participation rate across different test mandate on each test
df_act_sat_wide.groupby('test_mandate')[['participation_act','participation_sat']].mean()
# Out:
#               participation_act  participation_sat
# test_mandate
# ACT                    0.984524           0.124762
# ACT/SAT                0.561667           0.554667
# NO                     0.517963           0.441296
# SAT                    0.315185           0.849630

# %% [markdown]
# Data shows that the 35.29% of the states do not have any test mandate, and only 17.65% of states required to participate in SAT test. The states with test mandate tend to have higher participation rate on either of the test. Whereas the states without any test mandate only have 51.8% in ACT participation rate and 44.13% in SAT participation rate. This resulting that the test mandate is one of the factor that bring up the participation rate.

# %%
# Filtered bottom 10 college-going rate 2018
filtered_low = ['Alaska','Idaho','Utah','Arizona','Washington','Montana','West Virginia','Vermont','Oregon','Wyoming']

# %%
# assigned variable to the list of states that are bottom 10 college-going rate and without test mandate
filtered_low_no = list(df_act_sat_wide[(df_act_sat_wide.test_mandate =='NO') & 
                                       (df_act_sat_wide.state.isin(filtered_low))].state)
filtered_low_no
# Out:
# ['Alaska', 'Oregon', 'Vermont']

# %%
# filtered out the states in the filtered_low_no and check the average by test
df_act_sat_long[df_act_sat_long.state.isin(filtered_low_no)
               ].groupby(['test','state']).mean()
# Out:
#               participation        score  score_percent
# test state
# ACT  Alaska        0.453333    20.233333       0.562033
#      Oregon        0.413333    21.400000       0.594467
#      Vermont       0.243333    23.933333       0.664800
# SAT  Alaska        0.406667  1094.333333       0.683933
#      Oregon        0.473333  1112.333333       0.695200
#      Vermont       0.633333  1113.333333       0.695800

# %% [markdown]
# According to statisics from [NCHEMS](http://www.higheredinfo.org/dbrowser/?year=2018&level=nation&mode=data&state=&submeasure=63) shows the buttom 10 college-going rate were *'Alaska', 'Idaho', 'Utah', 'Arizona', 'Washington', 'Montana', 'West Virginia', 'Vermont', 'Oregon' and 'Wyoming'*. Only 3 states out of 10 states that without having any test mandate which is **Alaska**, **Oregon** and **Vermont**. Data shows that these states tend to have lower in participation rate of standardized test. It also shows low in standardized test participation rate may lead to lower college-going rate.

# %%
# Create ranking columns for median household income, state funding and k12 spending
df_act_sat_wide['income_rank'] = df_act_sat_wide.income.rank(ascending=False)
df_act_sat_wide['state_rank'] = df_act_sat_wide.state_funding.rank(ascending=False)
df_act_sat_wide['k12_rank'] = df_act_sat_wide.k12_spending.rank(ascending=False)

# %%
df_act_sat_wide[df_act_sat_wide.state.isin(filtered_low_no)].sort_values('state_fund_per_mincome')
# Out:
#       state  participation_act  score_percent_act  participation_sat  \
# 37   Oregon           0.413333           0.594467           0.473333
# 1    Alaska           0.453333           0.562033           0.406667
# 45  Vermont           0.243333           0.664800           0.633333
#
#     score_percent_sat code  total_uni  income  k12_spending  postsec_spending  \
# 37           0.695200   OR         78   62818         11340             37675
# 1            0.683933   AK          9   77640         17984             32630
# 45           0.695800   VT         22   61973         20370             35954
#
#     fed_funding  state_funding test_mandate  fed_fund_per_mincome  \
# 37          948          12981           NO              0.015091
# 1          3064          16252           NO              0.039464
# 45         1300          19134           NO              0.020977
#
#     state_fund_per_mincome  income_rank  state_rank  k12_rank
# ...

# %% [markdown]
# Data also shows that Oregon rank 21st nationwide in median household income, rank 24th nationwide in state funding per student and rank 30th nationwide in K12 spending per student.
#
# By filtering out Oregon, Alaska and Vermont, it shows that Oregon is the state having the lowest median household income (`$`62,818), lowest state funding per student(`$`12,981) and lowest in K12 spending per student(`$`11,340). On top of that, Oregon have below than national averages on these indicators where national average of median household income at `$`63,097.86, state funding per student at `$`13,641.51 and K12 spending per student at `$`12,953.35.

# %% [markdown]
# ### Summary Statistics

# %%
# describe and summarize the df_combine
df_combine.describe()
# Out:
#        participation_act_2017  score_percent_act_2017  participation_act_2018  \
# count               51.000000               51.000000               51.000000
# mean                 0.652549                0.597765                0.617255
# std                  0.321408                0.056128                0.340371
# min                  0.080000                0.494400                0.070000
# 25%                  0.310000                0.550000                0.285000
# 50%                  0.690000                0.594400                0.660000
# 75%                  1.000000                0.655600                1.000000
# max                  1.000000                0.708300                1.000000
#
#        score_percent_act_2018  participation_act_2019  score_percent_act_2019  \
# count               51.000000               51.000000               51.000000
# mean                 0.597118                0.586667                0.596239
# ...

# %%
# describe and summarize the df_act_sat_long
df_act_sat_long[['participation','score_percent']].describe()
# Out:
#        participation  score_percent
# count     306.000000     306.000000
# mean        0.533758       0.648436
# std         0.362843       0.077885
# min         0.020000       0.491700
# 25%         0.200000       0.589975
# 50%         0.550000       0.657800
# 75%         0.957500       0.693925
# max         1.000000       0.811200

# %%
# describe and summarize the df_act_sat_wide
df_act_sat_wide.describe()
# Out:
#        participation_act  score_percent_act  participation_sat  \
# count          51.000000          51.000000          51.000000
# mean            0.618824           0.597041           0.448693
# std             0.328698           0.057723           0.357529
# min             0.070000           0.494433           0.020000
# 25%             0.280000           0.554633           0.045000
# 50%             0.643333           0.594400           0.506667
# 75%             0.990000           0.650000           0.726667
# max             1.000000           0.707400           1.000000
#
#        score_percent_sat   total_uni        income  k12_spending  \
# count          51.000000   51.000000     51.000000     51.000000
# mean            0.699831  128.235294  63097.862745  12953.352941
# std             0.056861  132.675482  10715.134497   3929.868318
# min             0.604600    9.000000  45081.000000   7478.000000
# 25%             0.660000   38.000000  55560.500000  10098.500000
# ...

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# ### Visualize the Participation Rate and Score Percent in 2017, 2018 and 2019

# %%
# plot line plot for both test from year 2017 - 2019
ax1 = sns.set_style(style='darkgrid', rc=None )
fig, ax1 = plt.subplots(figsize=(6,6))

sns.lineplot(data= df_act_sat_long, x='year',y='participation',hue='test',ci=None, marker='o', sort = False, ax=ax1)
ax2 = ax1.twinx()
ax1.set_ylim(ymin=0,ymax=1)
ax1.set(xlabel='Year', ylabel='Participation Rate')

# plot bar plot for both test from year 2017 - 2019
sns.barplot(data= df_act_sat_long, x='year',y='participation',
            hue='test',ci=None, alpha=0.6, ax=ax2).set(title = 'ACT vs SAT Participation Rate 2017 - 2019')
ax2.set_ylim(ymin=0,ymax=1)
ax2.set(ylabel='Participation Rate')

plt.text(0 -0.3, 
         df_act_sat_long[(df_act_sat_long['year']=='2017')& (df_act_sat_long['test']=='ACT')]['participation'].mean() + 0.02,
         round(df_act_sat_long[(df_act_sat_long['year']=='2017')& (df_act_sat_long['test']=='ACT')]['participation'].mean(),4))
plt.text(1 -0.3, 
         df_act_sat_long[(df_act_sat_long['year']=='2018')& (df_act_sat_long['test']=='ACT')]['participation'].mean() + 0.02,
         round(df_act_sat_long[(df_act_sat_long['year']=='2018')& (df_act_sat_long['test']=='ACT')]['participation'].mean(),4))
plt.text(2 -0.3, 
         df_act_sat_long[(df_act_sat_long['year']=='2019')& (df_act_sat_long['test']=='ACT')]['participation'].mean() + 0.02,
         round(df_act_sat_long[(df_act_sat_long['year']=='2019')& (df_act_sat_long['test']=='ACT')]['participation'].mean(),4))
plt.text(0, 
         df_act_sat_long[(df_act_sat_long['year']=='2017')& (df_act_sat_long['test']=='SAT')]['participation'].mean() + 0.02,
         round(df_act_sat_long[(df_act_sat_long['year']=='2017')& (df_act_sat_long['test']=='SAT')]['participation'].mean(),4))
plt.text(1, 
         df_act_sat_long[(df_act_sat_long['year']=='2018')& (df_act_sat_long['test']=='SAT')]['participation'].mean() + 0.02,
         round(df_act_sat_long[(df_act_sat_long['year']=='2018')& (df_act_sat_long['test']=='SAT')]['participation'].mean(),4))
plt.text(2, 
         df_act_sat_long[(df_act_sat_long['year']=='2019')& (df_act_sat_long['test']=='SAT')]['participation'].mean() + 0.02,
         round(df_act_sat_long[(df_act_sat_long['year']=='2019')& (df_act_sat_long['test']=='SAT')]['participation'].mean(),4))

plt.savefig('../assets/act_sat_participation_barline.png')
plt.show();

# %% [markdown]
# - **Chart 1** clearly shows that the ACT have relatively higher participation rate as compared with SAT
# - ACT participation rate is decreasing over the years, while SAT participation rate is increasing

# %%
#matplotlib.rc_file_defaults()
ax1 = sns.set_style(style=None, rc=None )

fig, ax1 = plt.subplots(figsize=(6,6))

sns.barplot(data= df_act_sat_long, x='year',y='score_percent',
            hue='test',ci=None, alpha = 0.8).set(title='ACT vs SAT Score Percent 2017 - 2019')
ax1.set_ylim(ymin=0,ymax=1)
ax1.set(xlabel='Year', ylabel='Score Percent')


plt.text(0 -0.35, 
         df_act_sat_long[(df_act_sat_long['year']=='2017')& (df_act_sat_long['test']=='ACT')]['score_percent'].mean() + 0.02,
         round(df_act_sat_long[(df_act_sat_long['year']=='2017')& (df_act_sat_long['test']=='ACT')]['score_percent'].mean(),4))
plt.text(1 -0.35, 
         df_act_sat_long[(df_act_sat_long['year']=='2018')& (df_act_sat_long['test']=='ACT')]['score_percent'].mean() + 0.02,
         round(df_act_sat_long[(df_act_sat_long['year']=='2018')& (df_act_sat_long['test']=='ACT')]['score_percent'].mean(),4))
plt.text(2 -0.35, 
         df_act_sat_long[(df_act_sat_long['year']=='2019')& (df_act_sat_long['test']=='ACT')]['score_percent'].mean() + 0.02,
         round(df_act_sat_long[(df_act_sat_long['year']=='2019')& (df_act_sat_long['test']=='ACT')]['score_percent'].mean(),4))
plt.text(0 + 0.03, 
         df_act_sat_long[(df_act_sat_long['year']=='2017')& (df_act_sat_long['test']=='SAT')]['score_percent'].mean() + 0.02,
         round(df_act_sat_long[(df_act_sat_long['year']=='2017')& (df_act_sat_long['test']=='SAT')]['score_percent'].mean(),4))
plt.text(1 + 0.15, 
         df_act_sat_long[(df_act_sat_long['year']=='2018')& (df_act_sat_long['test']=='SAT')]['score_percent'].mean() + 0.02,
         round(df_act_sat_long[(df_act_sat_long['year']=='2018')& (df_act_sat_long['test']=='SAT')]['score_percent'].mean(),4))
plt.text(2 + 0.03, 
         df_act_sat_long[(df_act_sat_long['year']=='2019')& (df_act_sat_long['test']=='SAT')]['score_percent'].mean() + 0.02,
         round(df_act_sat_long[(df_act_sat_long['year']=='2019')& (df_act_sat_long['test']=='SAT')]['score_percent'].mean(),4))


plt.savefig('../assets/act_sat_score_barline.png')
plt.show();

# %% [markdown]
# - **Chart 2** shows not much different in term of score percent over the years, but averagely it still showing minor decreasing over the years for both test
#
# - From both charts it can summarize that the higher the participation rate of the test tend to have lower average score percent and vice versa

# %% [markdown]
# ### Comparing the Histogram for ACT and SAT Participation Rates in 2017, 2018 and 2019

# %%
# plot histogram for participation rate on both test in year 2017, 2018 and 2019
fig, (ax1,ax2,ax3) = plt.subplots(1,3, figsize=(14,5),sharey=True,constrained_layout=True)

sns.histplot(df_act_sat_long[df_act_sat_long.year == '2017'], x="participation", 
             hue="test",multiple="dodge",ax=ax1).set(ylim=(0, 25))
ax1.set_title('Histogram on ACT & SAT Participation rate 2017',fontsize=14)

sns.histplot(df_act_sat_long[df_act_sat_long.year == '2018'], x="participation", hue="test",multiple="dodge",ax=ax2)
ax2.set_title('Histogram on ACT & SAT Participation rate 2018',fontsize=14)

sns.histplot(df_act_sat_long[df_act_sat_long.year == '2019'], x="participation", hue="test",multiple="dodge",ax=ax3)
ax3.set_title('Histogram on ACT & SAT Participation rate 2019',fontsize=14)

plt.savefig('../assets/act_sat_participation_histogram.png',bbox_inches='tight')
plt.show();

# %% [markdown]
# - **Histogram 1** shows SAT have the highest number of states with participation rate *less than 20%*, while ACT have the highest number of states with *more than 80%* of participation rate in 2017
# - **Histogram 2** shows that the numbers of SAT participation increased as compared from 2017
# - **Histogram 3** shows further upward trends on the number of states with SAT participation rate more than 80%

# %% [markdown]
# ### Visualize the Relationships for Participation Rate and Score Percent on ACT and SAT

# %%
# use scatter plot to check the relationships on score and participation rate for different test
plt.figure(figsize=(13,6))
sns.set_style("white")
sns.scatterplot(data=df_act_sat_long, x="participation", y="score_percent", hue="test")
plt.grid(alpha=0.5)

plt.title('Participation Rate against Score Percent (2017-2019)',fontsize=15)
plt.xlabel('Average Participation Rate')
plt.ylabel('Average Score Percent')

plt.savefig('../assets/par_score_scatter.png')
plt.show();

# %% [markdown]
# - From the scatter plot, it shows that the average score for SAT is relatively higher as compared to ACT and it also shows that the higher the participation rate tend to have lower score on both ACT and SAT test
# - The Participation Rate have strong negative correlation with Score Percent as Pearson Correlation Coefficient shows -0.773170

# %%
# use scatter plot to check the relationships on score and participation rate for different test
plt.figure(figsize=(8,5))
sns.regplot(data=df_act_sat_wide, x="participation_sat", y="participation_act", ci = None)
plt.grid(alpha=0.5)

plt.title('Participation Rate SAT against Participation Rate ACT',fontsize=15)
plt.xlabel('SAT Participation Rate')
plt.ylabel('ACT Participation Rate')

plt.savefig('../assets/act_sat_participation_regp.png')
plt.show();

# %% [markdown]
# - **Reg plot 1** shows that the SAT and ACT participation rate inversely correlated with each other, the higher the participation rate on SAT test, tend to have lower participation rate in ACT test
#
# - The SAT Participation rate have strong negative correlation with ACT Participation rate as Pearson Correlation Coefficient shows -0.867447

# %% [markdown]
# ### Identifying the Target States with Low in Participation Rate for ACT & SAT

# %%
# plot line chart for Maine shows participation rate and score percent from 2017 - 2019
plt.figure(figsize=(15,5))
ax1 = sns.set_style("darkgrid", {"axes.facecolor": ".9"})
ax1 = plt.subplot(1,2,1)

ax1 = sns.lineplot(data=df_act_sat_long,
            x='year',y=df_act_sat_long[(df_act_sat_long['state']=='Maine')]['participation'],hue='test',
            ci=None, style='test' ,dashes = False, markers=['o','o'])

ax1.set_ylim(ymin=0,ymax=1)

plt.xlabel('Year',fontsize = 12)
plt.ylabel('Participation Rate',fontsize = 12)
plt.legend(loc='center right')
plt.title('Maine ACT vs SAT Participation Rate 2017 - 2019',fontsize = 15)

for i,participation in enumerate(df_act_sat_long[(df_act_sat_long['state']=='Maine')&
                                         (df_act_sat_long['test']=='ACT')]['participation']):
    plt.text(i-0.07,participation-0.05,f'{participation}')
    
for i,participation in enumerate(df_act_sat_long[(df_act_sat_long['state']=='Maine')&
                                         (df_act_sat_long['test']=='SAT')]['participation']):
    plt.text(i-0.07,participation-0.05,f'{participation}') 

ax2 = plt.subplot(1,2,2)
ax2 = sns.lineplot(data=df_act_sat_long,
            x='year',y=df_act_sat_long[(df_act_sat_long['state']=='Maine')]['score_percent'],hue='test',
            ci=None,style='test' ,dashes = False, markers=['o','o'])

ax2.set_ylim(ymin=0,ymax=1)
plt.xlabel('Year',fontsize = 12)
plt.ylabel('Score Percentage',fontsize = 12)
plt.legend()
plt.title('Maine ACT vs SAT Score Percentage 2017 - 2019',fontsize = 15)

for i,score in enumerate(df_act_sat_long[(df_act_sat_long['state']=='Maine')&
                                         (df_act_sat_long['test']=='ACT')]['score_percent']):
    plt.text(i-0.08,score+0.05,f'{score}')
    
for i,score in enumerate(df_act_sat_long[(df_act_sat_long['state']=='Maine')&
                                         (df_act_sat_long['test']=='SAT')]['score_percent']):
    plt.text(i-0.08,score-0.05,f'{score}')  

plt.savefig('../assets/maine_line.png')
plt.show();

# %% [markdown]
# - Maine have the lowest participation rate for ACT 3 years consecutively (2017-2019)
#
# - Maine have relatively high in SAT participation rate due to state test mandate to participate in SAT test
#
# - Both test score percent remain stable over the years (2017-2019)

# %%
# plot line chart for North Dakota shows participation rate and score percent from 2017 - 2019
plt.figure(figsize=(15,5))
ax1 = plt.subplot(1,2,1)

ax1 = sns.lineplot(data=df_act_sat_long,
            x='year',y=df_act_sat_long[(df_act_sat_long['state']=='North Dakota')]['participation'],hue='test',
            ci=None, style='test' ,dashes = False, markers=['o','o'])

ax1.set_ylim(ymin=0,ymax=1)

plt.xlabel('Year',fontsize = 12)
plt.ylabel('Participation Rate',fontsize = 12)
plt.legend()
plt.legend(loc='center right')
plt.title('North Dakota ACT vs SAT Participation Rate 2017 - 2019',fontsize = 15)

for i,participation in enumerate(df_act_sat_long[(df_act_sat_long['state']=='North Dakota')&
                                         (df_act_sat_long['test']=='ACT')]['participation']):
    plt.text(i-0.07,participation-0.05,f'{participation}')
    
for i,participation in enumerate(df_act_sat_long[(df_act_sat_long['state']=='North Dakota')&
                                         (df_act_sat_long['test']=='SAT')]['participation']):
    plt.text(i-0.07,participation+0.05,f'{participation}') 

ax2 = plt.subplot(1,2,2)
ax2 = sns.lineplot(data=df_act_sat_long,
            x='year',y=df_act_sat_long[(df_act_sat_long['state']=='North Dakota')]['score_percent'],hue='test',
            ci=None, style='test' ,dashes = False, markers=['o','o'])

ax2.set_ylim(ymin=0,ymax=1)
plt.xlabel('Year',fontsize = 12)
plt.ylabel('Score Percentage',fontsize = 12)
plt.legend()
plt.title('North Dakota ACT vs SAT Score Percentage 2017 - 2019',fontsize = 15)

for i,score in enumerate(df_act_sat_long[(df_act_sat_long['state']=='North Dakota')&
                                         (df_act_sat_long['test']=='ACT')]['score_percent']):
    plt.text(i-0.07,score-0.05,f'{score}')
    
for i,score in enumerate(df_act_sat_long[(df_act_sat_long['state']=='North Dakota')&
                                         (df_act_sat_long['test']=='SAT')]['score_percent']):
    plt.text(i-0.07,score+0.03,f'{score}')  

plt.savefig('../assets/north_dakota_line.png')
plt.show();

# %% [markdown]
# - North Dakota have the lowest participation rate for SAT 3 years consecutively (2017-2019)
#
# - North Dakota have relatively high in ACT participation rate due to state regulations

# %%
# plot line chart for Iowa shows participation rate and score percent from 2017 - 2019
plt.figure(figsize=(15,5))
ax1 = plt.subplot(1,2,1)

ax1 = sns.lineplot(data=df_act_sat_long,
            x='year',y=df_act_sat_long[(df_act_sat_long['state']=='Iowa')]['participation'],hue='test',
            ci=None, style='test' ,dashes = False, markers=['o','o'])

ax1.set_ylim(ymin=0,ymax=1)

plt.xlabel('Year',fontsize = 12)
plt.ylabel('Participation Rate',fontsize = 12)
plt.legend()
plt.title('Iowa ACT vs SAT Participation Rate 2017 - 2019',fontsize = 15)

for i,participation in enumerate(df_act_sat_long[(df_act_sat_long['state']=='Iowa')&
                                         (df_act_sat_long['test']=='ACT')]['participation']):
    plt.text(i-0.07,participation-0.05,f'{participation}')
    
for i,participation in enumerate(df_act_sat_long[(df_act_sat_long['state']=='Iowa')&
                                         (df_act_sat_long['test']=='SAT')]['participation']):
    plt.text(i-0.07,participation+0.05,f'{participation}') 

ax2 = plt.subplot(1,2,2)
ax2 = sns.lineplot(data=df_act_sat_long,
            x='year',y=df_act_sat_long[(df_act_sat_long['state']=='Iowa')]['score_percent'],hue='test',
            ci=None, style='test' ,dashes = False, markers=['o','o'])

ax2.set_ylim(ymin=0,ymax=1)
plt.xlabel('Year',fontsize = 12)
plt.ylabel('Score Percentage',fontsize = 12)
plt.legend()
plt.title('Iowa ACT vs SAT Score Percentage 2017 - 2019',fontsize = 15)

for i,score in enumerate(df_act_sat_long[(df_act_sat_long['state']=='Iowa')&
                                         (df_act_sat_long['test']=='ACT')]['score_percent']):
    plt.text(i-0.07,score-0.05,f'{score}')
    
for i,score in enumerate(df_act_sat_long[(df_act_sat_long['state']=='Iowa')&
                                         (df_act_sat_long['test']=='SAT')]['score_percent']):
    plt.text(i-0.07,score+0.04,f'{score}') 

plt.savefig('../assets/iowa_line.png')
plt.show();

# %% [markdown]
# - Combine both test participation rate, Iowa have the lowest average participation rate of 34.83%
# - Due to extremely low in SAT participation rate, however ACT participation rate of Iowa is above Nationwide ACT average participation rate of 61.88% over the years, it shows that Iowa have more preference to ACT than SAT

# %% [markdown]
# ### Target State - Oregon

# %%
# plot line chart for Oregon shows participation rate and score percent from 2017 - 2019
plt.figure(figsize=(15,5))
ax1 = plt.subplot(1,2,1)

ax1 = sns.lineplot(data=df_act_sat_long,
            x='year',y=df_act_sat_long[(df_act_sat_long['state']=='Oregon')]['participation'],hue='test',
            ci=None, style='test' ,dashes = False, markers=['o','o'])

ax1.set_ylim(ymin=0,ymax=1)

plt.xlabel('Year',fontsize = 12)
plt.ylabel('Participation Rate',fontsize = 12)
plt.legend()
plt.title('Oregon ACT vs SAT Participation Rate 2017 - 2019',fontsize = 15)

for i,participation in enumerate(df_act_sat_long[(df_act_sat_long['state']=='Oregon')&
                                         (df_act_sat_long['test']=='ACT')]['participation']):
    plt.text(i-0.07,participation-0.05,f'{participation}')
    
for i,participation in enumerate(df_act_sat_long[(df_act_sat_long['state']=='Oregon')&
                                         (df_act_sat_long['test']=='SAT')]['participation']):
    plt.text(i-0.07,participation+0.05,f'{participation}') 

ax2 = plt.subplot(1,2,2)
ax2 = sns.lineplot(data=df_act_sat_long,
            x='year',y=df_act_sat_long[(df_act_sat_long['state']=='Oregon')]['score_percent'],hue='test',
            ci=None, style='test' ,dashes = False, markers=['o','o'])

ax2.set_ylim(ymin=0,ymax=1)
plt.xlabel('Year',fontsize = 12)
plt.ylabel('Score Percentage',fontsize = 12)
plt.legend()
plt.title('Oregon ACT vs SAT Score Percentage 2017 - 2019',fontsize = 15)

for i,score in enumerate(df_act_sat_long[(df_act_sat_long['state']=='Oregon')&
                                         (df_act_sat_long['test']=='ACT')]['score_percent']):
    plt.text(i-0.07,score-0.05,f'{score}')
    
for i,score in enumerate(df_act_sat_long[(df_act_sat_long['state']=='Oregon')&
                                         (df_act_sat_long['test']=='SAT')]['score_percent']):
    plt.text(i-0.07,score+0.05,f'{score}')  

plt.savefig('../assets/oregon_line.png')
plt.show();

# %% [markdown]
# - Oregon is the only country that consistently having both ACT and SAT participation rate fall below 52% in 2017, 2018 and 2019
# - Low participation rate in SAT result in relatively higher average score (above 69%) as compared ACT having lower participation rate, the ACT score percent stil lesser than SAT score percent in 3 years.

# %% [markdown]
# ### Visualize the Variables Correlations with Participation Rate

# %%
# use scatter plot to check the relationships on score and participation rate for different test
sns.set_style("white")
plt.figure(figsize=(8,5))
sns.regplot(data=df_act_sat_wide, x="income", y="participation_sat", ci = None)
plt.grid(alpha=0.5)

plt.title('Median Household Income against SAT Participation rate',fontsize=15)
plt.xlabel('Median Household Income')
plt.ylabel('Average Participation Rate')

plt.savefig('../assets/household_income_regp.png')
plt.show();

# %% [markdown]
# - **Chart 1** shows that the Median Household Income having moderate correlation with the participation rate with Pearson’s correlation coefficient shows 0.62
#
# - The higher the median household income of the states tend to have higher participation rate

# %%
# use scatter plot to check the relationships on score and participation rate for different test
plt.figure(figsize=(8,5))
sns.regplot(data=df_act_sat_wide, x="total_uni", y="participation_sat", ci = None)
plt.grid(alpha=0.5)

plt.title('Number of Universities against SAT Participation rate',fontsize=15)
plt.xlabel('Number of Universities by state')
plt.ylabel('Average Participation Rate')

plt.savefig('../assets/uni_numbers_regp.png')
plt.show();

# %% [markdown]
# - **Chart 2** shows there is some forms of weak correlation between Number of Universities and participation rate with Pearson’s correlation coefficient shows only 0.19

# %%
# use scatter plot to check the relationships on score and participation rate for different test
plt.figure(figsize=(8,5))
sns.regplot(data=df_act_sat_wide, x="k12_spending", y="participation_sat", ci = None)
plt.grid(alpha=0.5)

plt.title('K12 Spending against SAT Participation rate',fontsize=15)
plt.xlabel('Average K12 Spending (per student)')
plt.ylabel('Average Participation Rate')

plt.savefig('../assets/k12_spending_regp.png',bbox_inches='tight')
plt.show();

# %% [markdown]
# - Chart shows the K12 spending per student with the participation rate tend to have upwards regression line
#
# - That is moderate correlation with Pearson’s correlation coefficient shows 0.48

# %%
# use scatter plot to check the relationships on score and participation rate for different test
plt.figure(figsize=(8,5))
sns.regplot(data=df_act_sat_wide, x="postsec_spending", y="participation_sat", ci = None)
plt.grid(alpha=0.5)

plt.title('Postsecondanry Spending against SAT Participation rate',fontsize=15)
plt.xlabel('Average Postsecondanry Spending (per student)')
plt.ylabel('Average Participation Rate')

plt.savefig('../assets/postsec_spending_regp.png',bbox_inches='tight')
plt.show();

# %% [markdown]
# - Postsecondary spending per student shows weak correlation with participation rate with Pearson’s correlation coefficient shows only 0.11

# %%
# use scatter plot to check the relationships on score and participation rate for different test
plt.figure(figsize=(8,5))
sns.regplot(data=df_act_sat_wide, x="fed_funding", y="participation_sat", ci = None)
plt.grid(alpha=0.5)

plt.title('Federal Funding against SAT Participation rate',fontsize=15)
plt.xlabel('Average Federal Funding (per student)')
plt.ylabel('Average Participation Rate')

plt.savefig('../assets/fed_funding_regp.png',bbox_inches='tight')
plt.show();

# %% [markdown]
# - Federal funding per student shows weak negative correlation with participation rate with Pearson’s correlation coefficient shows only - 0.072

# %%
# use scatter plot to check the relationships on score and participation rate for different test
plt.figure(figsize=(8,5))
sns.regplot(data=df_act_sat_wide, x="state_funding", y="participation_sat", ci = None)
plt.grid(alpha=0.5)

plt.title('State Funding against SAT Participation rate',fontsize=15)
plt.xlabel('Average State Funding (per student)')
plt.ylabel('Average Participation Rate')

plt.savefig('../assets/state_funding_regp.png',bbox_inches='tight')
plt.show();

# %% [markdown]
# - Chart shows the state funding per student tend to have upwards regression line
#
# - There is moderate correlation shows between state funding per student and participation rate with participation rate with Pearson’s correlation coefficient shows 0.5

# %% [markdown]
# ### Correlation Heatmap for All Variables

# %%
# Use Heatmap to show the correlation on df_act_sat_wide
plt.figure(figsize = (20,8))

# Get correlation of variables.
corr = df_act_sat_wide.loc[:,'state':'state_fund_per_mincome'].corr()

# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Plot our correlation heatmap, while masking the upper triangle to be white.
with sns.axes_style("white"):
    sns.heatmap(corr, mask = mask, square = True, annot = True, vmin = -1, vmax = 1, linewidths = .5) #, 
                #cbar_kws={'orientation': 'horizontal'})
    
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.title('Correlation Heat Map for ACT SAT Data ',fontsize=15)

plt.savefig('../assets/heatmap.png',bbox_inches='tight');

# %% [markdown]
# - Participation rate for both ACT and SAT having strong negative correlated (mirror) to each other as it shows -0.86
#
# - Median Household Income have 0.49 moderately correlated with SAT participation rate
#
# - State Funding per student have 0.5 moderately correlated with SAT participation rate
#
# - The rest of the data do not shows any strong correlation with participation rate

# %% [markdown]
# ### Participation Rate on each Test Mandate

# %%
# plot the Bar Chart to show the participation rate for each test mandate
test_mandate_order = ['ACT','SAT','ACT/SAT','NO']
ax = df_act_sat_wide.groupby('test_mandate')[['participation_act',
                                         'participation_sat']].mean().loc[['ACT','SAT',
                                                                           'ACT/SAT','NO']].plot(kind='bar',stacked=False)

handles, _ = ax.get_legend_handles_labels()

plt.xticks(rotation=0)
plt.xlabel('Test Mandate')
plt.ylabel('Average Participation Rate')
plt.title('Average Participation Rate by Test Mandate')
plt.axhline(df_act_sat_long.participation.mean(), ls='--',color='black')

plt.legend(labels = ['National Test Participation','ACT participation rate','SAT participation rate'])
plt.grid()
plt.show();

# %% [markdown]
# - From the bar chart it shows that the states with either ACT or SAT mandate will have higher test participation rate
# - National average test participation rate is 53.38% and the states without test mandate fall below the national average for both ACT and SAT participation rate

# %% [markdown]
# ### Median Household Income by US States

# %%
#Nationwide Median Household Income and average
order = df_act_sat_wide.sort_values('income',ascending=False).state
clrs = ['red' if (x == 'Oregon') else 'grey' for x in order ]

plt.figure(figsize=(15,5))
sns.barplot(data= df_act_sat_wide, x='state',y='income',
            ci=None, order= order, palette=clrs).set(title = 'US States Median Household Income')


plt.axhline(df_act_sat_wide.income.mean(), ls='--')
plt.xticks(rotation=90)
plt.ylabel('Median Household Income')
plt.show();

# %%
#Bottom 10 College-Going Rate States without ACT or SAT Test Mandate Median Household Income
order = df_act_sat_wide[df_act_sat_wide.state.isin(filtered_low_no)].sort_values('income',ascending=False).state
clrs = ['red' if (x == 'Oregon') else 'grey' for x in order ]

plt.figure(figsize=(6,5))
plt.grid(alpha=0.5)

sns.barplot(data= df_act_sat_wide[df_act_sat_wide.state.isin(filtered_low_no)], x='state',y='income',
            ci=None, order= order, palette=clrs ).set(title = 'US States Median Household Income')

plt.axhline(df_act_sat_wide.income.mean(), ls='--')
plt.ylabel('Median Household Income')
plt.savefig('../assets/oregon_buttom_income.png')
plt.show();

# %% [markdown]
# - Oregon rank 21st in Median Household income nationwide
# - Alaska, Vermont and Oregon are the only 3 out of 10 states that having bottom 10 college-going rate and without having Standardized Test Mandate
# - The state have Average Median Household Income of `$`62,818, and it is fall below the National Average Median Household Income of `$`63,097.86

# %% [markdown]
# ### State and Local Funding per Student by US States

# %%
#Nationwide State Funding Per Student and average
order_2 = df_act_sat_wide.sort_values('state_funding',ascending=False).state
clrs_2 = ['red' if (x == 'Oregon') else 'grey' for x in order_2 ]

plt.figure(figsize=(15,5))
sns.barplot(data= df_act_sat_wide, x='state',y='state_funding',
            ci=None, order= order_2, palette=clrs_2 ).set(title = 'US States State and Local Funding per Student')

plt.axhline(df_act_sat_wide.state_funding.mean(), ls='--')
plt.xticks(rotation=90)
plt.ylabel('State and Local Funding (per Student)')
plt.show();

# %%
#Bottom 10 College-Going Rate States without ACT or SAT Test Mandate State Funding per student
order = df_act_sat_wide[df_act_sat_wide.state.isin(filtered_low_no)].sort_values('state_funding',ascending=False).state
clrs = ['red' if (x == 'Oregon') else 'grey' for x in order ]

plt.figure(figsize=(6,5))
plt.grid(alpha=0.5)
sns.barplot(data= df_act_sat_wide[df_act_sat_wide.state.isin(filtered_low_no)], x='state',y='state_funding',
            ci=None, order= order, palette=clrs ).set(title = 'US States State and Local Funding per Student')

plt.axhline(df_act_sat_wide.state_funding.mean(), ls='--')
plt.ylabel('State and Local Funding (per Student)')
plt.savefig('../assets/oregon_buttom_funding.png')
plt.show();

# %% [markdown]
# - Oregon rank 24th in State Funding per Student nationwide
#
# - Average State Funding per student of `$`12,981, while National Average State Funding per student at `$`13,641.51
#
# - Oregon have the lowest State Funding per student out of Alaska, Vermont and Oregon

# %% [markdown]
# ### K12 Spending per Student by US States

# %%
#Nationwide K12 Spending Per Student and average
order_3 = df_act_sat_wide.sort_values('k12_spending',ascending=False).state
clrs_3 = ['red' if (x == 'Oregon') else 'grey' for x in order_3 ]

plt.figure(figsize=(15,5))
sns.barplot(data= df_act_sat_wide, x='state',y='k12_spending',
            ci=None, order= order_3, 
            palette=clrs_3).set(title = 'US States K12 Spending per Student')

plt.axhline(df_act_sat_wide.k12_spending.mean(), ls='--')
plt.xticks(rotation=90)
plt.ylabel('K12 Spending (per Student)')
plt.show();

# %%
#Bottom 10 College-Going Rate States without ACT or SAT Test Mandate K12 spending per student
order = df_act_sat_wide[df_act_sat_wide.state.isin(filtered_low_no)].sort_values('k12_spending',ascending=False).state
clrs = ['red' if (x == 'Oregon') else 'grey' for x in order ]

plt.figure(figsize=(6,5))
plt.grid(alpha=0.5)
sns.barplot(data= df_act_sat_wide[df_act_sat_wide.state.isin(filtered_low_no)], x='state',y='k12_spending',
            ci=None, order= order, palette=clrs ).set(title = 'US States K12 Spending per Student')

plt.axhline(df_act_sat_wide.k12_spending.mean(), ls='--')
plt.ylabel('K12 Spending (per Student)')
plt.savefig('../assets/oregon_buttom_spending.png')
plt.show();

# %% [markdown]
# - Oregon rank 30th in K12 Spending per Student nationwide
#
# - Average K12 Spending per student of `$`11,340, while National Average K12 Spending at `$`12,953.35
#
# - Oregon have the lowest K12 Spending per student out of Alaska, Vermont and Oregon

# %% [markdown]
# ### Citations:
#
# 1. https://www.edweek.org/teaching-learning/which-states-require-students-to-take-the-sat-or-act
# 2. https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice
# 3. https://educationdata.org/public-education-spending-statistics
# 4. https://www.edweek.org/teaching-learning/sat-scores-see-slight-increase-as-test-taking-surges/2018/10
# 5. https://collegescorecard.ed.gov/data/
# 6. https://worldpopulationreview.com/states/state-abbreviations
# 7. https://www.oregon.gov/highered/research/Pages/educational-attainment.aspx
# 8. http://www.higheredinfo.org/dbrowser/?year=2018&level=nation&mode=data&state=&submeasure=63
# 9. https://www.census.gov/search-results.html?q=median+income+by+state&page=1&stateGeo=none&searchtype=web&cssp=SERP&_charset_=UTF-8
# 10. https://collegescorecard.ed.gov/data/

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# ### Findings:
# 1) Participation rate in ACT and SAT tend to be negative correlated (mirror) to each other, it means that the higher the SAT participation rate tend to have lower ACT participation rate. State with test mandate requirements tend to have higher participation rate than the states without any test mandate requirements. 35.29% of US States with no test mandate only have average 51.8% in ACT participation rate and 44.13% in SAT participation rate.
#
# 2) Either of the test also tend to be negative correlated with the score percent, it means that the higher the test participation rate tend to have lower test score percent. It is mainly because of the average may be lower and the more students taking the test probably rank relatively low in their class are applying to the selective institution of higher education.
#
# 3) Oregon rank 21st nationwide in median household income, rank 24th nationwide in state funding per student and rank 30th nationwide in K12 spending per student. It rank bottom out of the states with bottom 10 college-going rate and without test mandate for K12 spending per student and State and Local funding per student. However, all 3 variables of Oregon shows fall below national averages. Pearson's Correlation Coefficient shows there is 0.49 in Median Household Income correlated to SAT participation rate, 0.48 in K12 Spending per student to SAT participation rate and 0.5 in State and Local funding per student to SAT participation rate.
#
# ### Recommendations:
# 1) Oregon can decide to mandate either one of the standardized test and focus the efforts to increase participation rate of chosen test. By negotiating the term with SAT and ACT to bring the more benefits or financial aid to the high school of Oregon and test participants, example School Day and Test Fee Waiver.
#
# 2) Oregon state can aim to provide more budget to fund the students for having free to participate in standardized test or minimally can subsidize the test to further support the low income family as well as cultivating a college-going culture in the state.
#
# 3) The state can also provide more resources to support the test participants, example free online test preparation materials or  high school to provide additional resources for students to prepare standardize test.
#
# 4) The state can launch some marketing campaigns or organize University and college readiness fair for the high school, to share more about the enrollment requirements and supports example, college scholarships, financial aid and student loan for the college tuition fee, so the students from low income family have the more opportunities to enroll and it also create stronger awareness to the students and public for the importance and support for college-going.
